# %%
from flexddm.models.nsbi_models import nDDMfz, nDMCfz, nSSPfz, nDSTPfz 
from flexddm.main import validation

# %% [markdown]
# All outputs figures are in the folder [validation](./validation/model_validation.png).

# %%
ddm = nDDMfz() 
ssp = nSSPfz()
dmc = nDMCfz()
dstp = nDSTPfz() 

validation(
    models=[ddm, ssp, dmc, dstp], 
    param_recovery_simulations=50, 
    model_recovery_simulations=50,
    parameter_recovery=True,
    model_recovery=False,
)

# %%
ddm = nDDMfz() 
ssp = nSSPfz()
dmc = nDMCfz()
dstp = nDSTPfz() 

validation(
    models=[ddm, ssp, dmc, dstp], 
    param_recovery_simulations=50, 
    model_recovery_simulations=50,
    parameter_recovery=False,
    model_recovery=True,
)
